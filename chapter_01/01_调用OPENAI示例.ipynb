# %% [markdown]
# 使用OpenAI SDK 来调用API（大部分模型兼容）

# %% [markdown]
# ## 1、传递prompt，调用client.chat.completions.create

# %%
from openai import OpenAI
import dotenv

dotenv.load_dotenv()

# 构造一个客户端
client = OpenAI(

)
res = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{"role": "user", "content": "你是谁"}]
)

# %% [markdown]
# ## 2、获取模型回复结果

# %%
res.choices[0].message.content
# Out:
# '我是一个由OpenAI开发的人工智能助手，旨在回答问题和提供信息。如果你有任何问题或需要帮助，请随时问我！'
